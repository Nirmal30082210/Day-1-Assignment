# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
condenser_df = pd.read_csv("D:/OneDrive - Adani/ACoE DATA/BOOT CAMP 1/DAY 1/Regression_data.csv")

# %%
condenser_df
# Out:
#         Unnamed: 0           time  CW TO COND1 IL1 PR  LOAD ACTUAL-   \
# 0                0  1670295360000             1.22877            NaN
# 1                1  1670295420000             1.23106            NaN
# 2                2  1670295480000             1.22968            NaN
# 3                3  1670962920000             1.46363      127.76267
# 4                4  1674543120000             1.46042      134.94850
# ...            ...            ...                 ...            ...
# 545835      545835  1724306640000             1.77494      136.89330
# 545836      545836  1724306700000             1.77082      136.11043
# 545837      545837  1724306760000             1.76578      135.67368
# 545838      545838  1724306820000             1.76853      136.27524
# 545839      545839  1724306880000             1.76395      135.69839
#
#         condenser vacuum  CW TEMP COND1 IL1
# 0                    NaN                NaN
# 1                    NaN                NaN
# ...

# %%
condenser_df.describe()
# Out:
#           Unnamed: 0          time  CW TO COND1 IL1 PR  LOAD ACTUAL-   \
# count  545840.000000  5.458400e+05       545840.000000  534786.000000
# mean   272919.500000  1.704615e+12            1.400146      94.207934
# std    157570.579805  1.196558e+10            0.413272      60.410951
# min         0.000000  1.670295e+12            0.000000       0.000000
# 25%    136459.750000  1.694933e+12            1.139500       0.181290
# 50%    272919.500000  1.704759e+12            1.493840     128.388960
# 75%    409379.250000  1.714917e+12            1.634850     136.044490
# max    545839.000000  1.724307e+12            2.428700     168.916370
#
#        condenser vacuum  CW TEMP COND1 IL1
# count     533757.000000      533710.000000
# mean           0.323196          31.380364
# std            0.387707           2.233825
# min            0.000000           0.000000
# 25%            0.098660          30.505780
# 50%            0.102870          31.717390
# ...

# %% [markdown]
# 1. identify null values & impute the null values

# %%
condenser_df.isnull().sum()
# Out:
# Unnamed: 0                0
# time                      0
# CW TO COND1 IL1 PR        0
# LOAD ACTUAL-          11054
# condenser vacuum      12083
# CW TEMP COND1 IL1     12130
# dtype: int64

# %%
condenser_df[condenser_df["LOAD ACTUAL- "].isnull()]
# Out:
#         Unnamed: 0           time  CW TO COND1 IL1 PR  LOAD ACTUAL-   \
# 0                0  1670295360000             1.22877            NaN
# 1                1  1670295420000             1.23106            NaN
# 2                2  1670295480000             1.22968            NaN
# 1147          1147  1680398880000             1.49201            NaN
# 41336        41336  1689234540000             1.46546            NaN
# ...            ...            ...                 ...            ...
# 402836      402836  1714469460000             1.47828            NaN
# 402845      402845  1714471200000             1.47461            NaN
# 402848      402848  1714471800000             1.47370            NaN
# 402853      402853  1714472340000             1.47416            NaN
# 465650      465650  1718723040000             1.85277            NaN
#
#         condenser vacuum  CW TEMP COND1 IL1
# 0                    NaN                NaN
# 1                    NaN                NaN
# ...

# %%
condenser_df[condenser_df["condenser vacuum"].isnull()]
# Out:
#         Unnamed: 0           time  CW TO COND1 IL1 PR  LOAD ACTUAL-   \
# 0                0  1670295360000             1.22877            NaN
# 1                1  1670295420000             1.23106            NaN
# 2                2  1670295480000             1.22968            NaN
# 277            277  1676462750534             1.46958      130.82819
# 1147          1147  1680398880000             1.49201            NaN
# ...            ...            ...                 ...            ...
# 402846      402846  1714471260000             1.47507      121.55747
# 402848      402848  1714471800000             1.47370            NaN
# 402849      402849  1714471920000             1.47324      122.08488
# 402853      402853  1714472340000             1.47416            NaN
# 465650      465650  1718723040000             1.85277            NaN
#
#         condenser vacuum  CW TEMP COND1 IL1
# 0                    NaN                NaN
# 1                    NaN                NaN
# ...

# %%
condenser_df[condenser_df["CW TEMP COND1 IL1"].isnull()]
# Out:
#         Unnamed: 0           time  CW TO COND1 IL1 PR  LOAD ACTUAL-   \
# 0                0  1670295360000             1.22877            NaN
# 1                1  1670295420000             1.23106            NaN
# 2                2  1670295480000             1.22968            NaN
# 298            298  1676464151853             1.46958      130.82819
# 1147          1147  1680398880000             1.49201            NaN
# ...            ...            ...                 ...            ...
# 402848      402848  1714471800000             1.47370            NaN
# 402852      402852  1714472100000             1.47553      121.79646
# 402853      402853  1714472340000             1.47416            NaN
# 402854      402854  1714472460000             1.47645      121.70581
# 465650      465650  1718723040000             1.85277            NaN
#
#         condenser vacuum  CW TEMP COND1 IL1
# 0                    NaN                NaN
# 1                    NaN                NaN
# ...

# %%
df1 = condenser_df[condenser_df["CW TEMP COND1 IL1"].notna()]

# %%
df1
# Out:
#         Unnamed: 0           time  CW TO COND1 IL1 PR  LOAD ACTUAL-   \
# 3                3  1670962920000             1.46363      127.76267
# 4                4  1674543120000             1.46042      134.94850
# 5                5  1674543180000             1.45905      134.74248
# 6                6  1674907560000             1.46958      130.82819
# 7                7  1676440204790             1.46958      130.82819
# ...            ...            ...                 ...            ...
# 545835      545835  1724306640000             1.77494      136.89330
# 545836      545836  1724306700000             1.77082      136.11043
# 545837      545837  1724306760000             1.76578      135.67368
# 545838      545838  1724306820000             1.76853      136.27524
# 545839      545839  1724306880000             1.76395      135.69839
#
#         condenser vacuum  CW TEMP COND1 IL1
# 3                0.10154           29.84823
# 4                0.09976           29.74444
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0              0
# time                    0
# CW TO COND1 IL1 PR      0
# LOAD ACTUAL-            0
# condenser vacuum      722
# CW TEMP COND1 IL1       0
# dtype: int64

# %%
condenser_df = df1[df1["condenser vacuum"].notna()]

# %%
condenser_df.isnull().sum()
# Out:
# Unnamed: 0            0
# time                  0
# CW TO COND1 IL1 PR    0
# LOAD ACTUAL-          0
# condenser vacuum      0
# CW TEMP COND1 IL1     0
# dtype: int64

# %%
condenser_df = condenser_df.drop(columns=["time","Unnamed: 0"])

# %% [markdown]
# 2. filter data based on domain knowledge

# %%
condenser_df
# Out:
#         CW TO COND1 IL1 PR  LOAD ACTUAL-   condenser vacuum  CW TEMP COND1 IL1
# 3                  1.46363      127.76267           0.10154           29.84823
# 4                  1.46042      134.94850           0.09976           29.74444
# 5                  1.45905      134.74248           0.09976           29.74444
# 6                  1.46958      130.82819           0.09838           29.88284
# 7                  1.46958      130.82819           0.09838           29.88284
# ...                    ...            ...               ...                ...
# 545835             1.77494      136.89330           0.09912           33.03334
# 545836             1.77082      136.11043           0.09912           33.06799
# 545837             1.76578      135.67368           0.09907           32.99871
# 545838             1.76853      136.27524           0.09907           33.06799
# 545839             1.76395      135.69839           0.09889           33.10262
#
# ...

# %%
condenser_df.describe()
# Out:
#        CW TO COND1 IL1 PR  LOAD ACTUAL-   condenser vacuum  CW TEMP COND1 IL1
# count       532988.000000  532988.000000     532988.000000      532988.000000
# mean             1.395592      94.216660          0.323418          31.381051
# std              0.416211      60.418409          0.387840           2.234732
# min              0.000000       0.000000          0.000000           0.000000
# 25%              1.101500       0.181290          0.098660          30.505780
# 50%              1.493840     128.405440          0.102870          31.717390
# 75%              1.633930     136.060970          0.244553          32.721630
# max              2.428700     168.916370          1.000000          36.048230

# %%
condenser_df = condenser_df[condenser_df["LOAD ACTUAL- "]>50]

# %%
condenser_df.describe()
# Out:
#        CW TO COND1 IL1 PR  LOAD ACTUAL-   condenser vacuum  CW TEMP COND1 IL1
# count       378867.000000  378867.000000     378867.000000      378867.000000
# mean             1.612179     132.473532          0.100997          31.869561
# std              0.165082       8.570178          0.005379           1.379666
# min              0.000000      50.168930          0.000000           0.000000
# 25%              1.482850     127.194060          0.097740          30.782680
# 50%              1.543290     132.888350          0.101040          32.063640
# 75%              1.768070     138.491960          0.104340          32.998710
# max              2.428700     168.916370          0.155890          36.048230

# %%
condenser_df = condenser_df[condenser_df["condenser vacuum"]!=0]

# %%
condenser_df.describe()
# Out:
#        CW TO COND1 IL1 PR  LOAD ACTUAL-   condenser vacuum  CW TEMP COND1 IL1
# count       378864.000000  378864.000000     378864.000000      378864.000000
# mean             1.612188     132.473530          0.100998          31.869728
# std              0.165041       8.570208          0.005371           1.377727
# min              1.021840      50.168930          0.066430          27.392300
# 25%              1.482850     127.194060          0.097740          30.782680
# 50%              1.543290     132.888350          0.101040          32.063640
# 75%              1.768070     138.491960          0.104340          32.998710
# max              2.428700     168.916370          0.155890          36.048230

# %%
condenser_df
# Out:
#         CW TO COND1 IL1 PR  LOAD ACTUAL-   condenser vacuum  CW TEMP COND1 IL1
# 3                  1.46363      127.76267           0.10154           29.84823
# 4                  1.46042      134.94850           0.09976           29.74444
# 5                  1.45905      134.74248           0.09976           29.74444
# 6                  1.46958      130.82819           0.09838           29.88284
# 7                  1.46958      130.82819           0.09838           29.88284
# ...                    ...            ...               ...                ...
# 545835             1.77494      136.89330           0.09912           33.03334
# 545836             1.77082      136.11043           0.09912           33.06799
# 545837             1.76578      135.67368           0.09907           32.99871
# 545838             1.76853      136.27524           0.09907           33.06799
# 545839             1.76395      135.69839           0.09889           33.10262
#
# ...

# %%
condenser_df.describe()
# Out:
#        CW TO COND1 IL1 PR  LOAD ACTUAL-   condenser vacuum  CW TEMP COND1 IL1
# count       378864.000000  378864.000000     378864.000000      378864.000000
# mean             1.612188     132.473530          0.100998          31.869728
# std              0.165041       8.570208          0.005371           1.377727
# min              1.021840      50.168930          0.066430          27.392300
# 25%              1.482850     127.194060          0.097740          30.782680
# 50%              1.543290     132.888350          0.101040          32.063640
# 75%              1.768070     138.491960          0.104340          32.998710
# max              2.428700     168.916370          0.155890          36.048230

# %% [markdown]
# 3. find 5 point stats for independent variables

# %%
condenser_df.median()
# Out:
# CW TO COND1 IL1 PR      1.54329
# LOAD ACTUAL-          132.88835
# condenser vacuum        0.10104
# CW TEMP COND1 IL1      32.06364
# dtype: float64

# %%
condenser_df.mode().iloc[0]
# Out:
# CW TO COND1 IL1 PR      1.47645
# LOAD ACTUAL-          127.91100
# condenser vacuum        0.10163
# CW TEMP COND1 IL1      32.89481
# Name: 0, dtype: float64

# %%
condenser_df.describe()
# Out:
#        CW TO COND1 IL1 PR  LOAD ACTUAL-   condenser vacuum  CW TEMP COND1 IL1
# count       378864.000000  378864.000000     378864.000000      378864.000000
# mean             1.612188     132.473530          0.100998          31.869728
# std              0.165041       8.570208          0.005371           1.377727
# min              1.021840      50.168930          0.066430          27.392300
# 25%              1.482850     127.194060          0.097740          30.782680
# 50%              1.543290     132.888350          0.101040          32.063640
# 75%              1.768070     138.491960          0.104340          32.998710
# max              2.428700     168.916370          0.155890          36.048230

# %% [markdown]
# 4. find relationship between X & Y and within independent variables

# %%
plt.figure(figsize=(6,6))
sns.heatmap(condenser_df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 5. Plot distribution of Y & give insights

# %%
sns.boxplot(condenser_df["condenser vacuum"])
# Out:
# <Axes: ylabel='condenser vacuum'>

# %%
sns.distplot(condenser_df["condenser vacuum"])
# Out:
# C:\Users\30016154\AppData\Local\Temp\ipykernel_3272\2725546174.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(condenser_df["condenser vacuum"])
# <Axes: xlabel='condenser vacuum', ylabel='Density'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data loading method)
data = {
    'Unnamed: 0': [1, 2, 3, 4],
  
}

# Create DataFrame
df = pd.DataFrame(data)

# Create box plots for all numerical columns
plt.figure(figsize=(10, 5))
df.boxplot()
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.title('Box Plot for All row')
plt.show()

# %%
data = {
  'time': [1.704615e+12, 1.704616e+12, 1.704617e+12, 1.704618e+12],
  
}

# Create DataFrame
df = pd.DataFrame(data)

# Create box plots for all numerical columns
plt.figure(figsize=(10, 5))
df.boxplot()
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.title('Box Plot for All row')
plt.show()

# %%
data = {
  'CW TO COND1 IL PR': [1.4, 1.5, 1.6, 1.7],
  
}

# Create DataFrame
df = pd.DataFrame(data)

# Create box plots for all numerical columns
plt.figure(figsize=(10, 5))
df.boxplot()
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.title('Box Plot for All row')
plt.show()

# %%
data = {
  'LOAD ACTUAL-': [94.2, 95.3, 96.4, 97.5],
  
}

# Create DataFrame
df = pd.DataFrame(data)

# Create box plots for all numerical columns
plt.figure(figsize=(10, 5))
df.boxplot()
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.title('Box Plot for All row')
plt.show()

# %%
data = {
  'CW TEMP COND1 IL': [31.38, 31.39, 31.40, 31.41]
  
}

# Create DataFrame
df = pd.DataFrame(data)

# Create box plots for all numerical columns
plt.figure(figsize=(10, 5))
df.boxplot()
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.title('Box Plot for All row')
plt.show()
